# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine('postgresql://jayz:localhost@localhost:5432/covid1')

# %%
covid = pd.read_csv('./COVID1/corona.csv')

# %%
covid.to_sql('covid', engine, index=False)

# %%
query = 'SELECT * FROM covid;'
df = pd.read_sql(query, engine)

df.head(100)
# Out:
#      test_date cough fever sore_throat shortness_of_breath head_ache  \
# 0   2020-04-30     0     0           0                   0         0
# 1   2020-04-30     1     0           0                   0         0
# 2   2020-04-30     0     1           0                   0         0
# 3   2020-04-30     1     0           0                   0         0
# 4   2020-04-30     1     0           0                   0         0
# ..         ...   ...   ...         ...                 ...       ...
# 95  2020-04-30     0     0           0                   0         0
# 96  2020-04-30     0     0           0                   0         0
# 97  2020-04-30     1     1           0                   0         0
# 98  2020-04-30     0     0           0                   0         0
# 99  2020-04-30     0     0           0                   0         0
#
#    corona_result age_60_and_above  gender test_indication
# 0       negative             None  female           Other
# ...

# %%
query = 'SELECT gender,count(*) FROM covid group by 1;'
df = pd.read_sql(query, engine)

df
# Out:
#    gender   count
# 0    None   19563
# 1  female  130158
# 2    male  129127

# %%
query = 'SELECT corona_result,count(*) FROM covid group by 1;'
df = pd.read_sql(query, engine)

df
# Out:
#   corona_result   count
# 0      negative  260227
# 1         other    3892
# 2      positive   14729
